# %% [markdown]
# Ejercicio 1:
#
# Contamos con los datos de consumo de agua de la CDMX obtenidos del portal de datos abiertos de la CDMX. Este set de datos supuestamente contiene "información bimestral de suministro de agua a nivel manzana, considerando la facturación por servicio de consumo medido y promedio"
#
# Queremos generar el data profiling de estos datos.

# %%
import pandas as pd
import os

# %%
os.getcwd() #Da la ruta actual del directorio
# Out:
# 'C:\\Users\\dor3l\\Documents\\Escuela\\ITAM\\CienciaDeDatos\\2019\\ICD'

# %%
print(os.listdir(os.getcwd())) #Genera listado de los archivos en la ruta
# Out:
# ['.ipynb_checkpoints', 'consumo-agua.csv', 'consumo-agua.xls', 'ICD', 'Practica1_EDA.ipynb', 'Untitled-Copy1.ipynb']

# %%
df_consumo_agua=pd.read_csv('consumo-agua.csv',sep=';') #Carga CSV

# %%
#df_consumo_agua.sample(5) #Muestra aleatoria de 5 registros
df_consumo_agua.head() #Muestra los primeros 5 registros en la tabla de datos
# Out:
#                       Geo Point  \
# 0  19.4982924872,-99.1990438826
# 1  19.4988910559,-99.2009080554
# 2  19.4808107353,-99.2087681126
# 3  19.4815775288,-99.2034616053
# 4  19.4794098214,-99.2027692099
#
#                                            Geo Shape  consumo_total_mixto  \
# 0  {"type": "MultiPolygon", "coordinates": [[[[-9...               307.09
# 1  {"type": "MultiPolygon", "coordinates": [[[[-9...                63.78
# 2  {"type": "MultiPolygon", "coordinates": [[[[-9...               129.81
# 3  {"type": "MultiPolygon", "coordinates": [[[[-9...               142.20
# 4  {"type": "MultiPolygon", "coordinates": [[[[-9...                71.38
#
#    anio        nomgeo  consumo_prom_dom  consumo_total_dom      alcaldia  \
# 0  2019  Azcapotzalco         41.430000             455.73  AZCAPOTZALCO
# 1  2019  Azcapotzalco         61.337142             429.36  AZCAPOTZALCO
# 2  2019  Azcapotzalco         24.724412             840.63  AZCAPOTZALCO
# ...

# %% [markdown]
# ¿Cuántas variables tenemos?
#
# ¿Cuántas observaciones tenemos?

# %%
df_consumo_agua.shape #Indica el número de filas y columnas
#len(df_consumo_agua) #Observaciones
#df_consumo_agua.size #Total de elementos
# Out:
# (71102, 17)

# %% [markdown]
# 17 variables y 71,102 observaciones

# %% [markdown]
# ¿Cuántas observaciones únicas tenemos por variable?

# %%
df_consumo_agua.nunique()
# Out:
# Geo Point               22930
# Geo Shape               22922
# consumo_total_mixto     24339
# anio                        1
# nomgeo                     17
# consumo_prom_dom        52060
# consumo_total_dom       47051
# alcaldia                   16
# colonia                  1340
# consumo_prom_mixto      31911
# consumo_total           56015
# consumo_prom            62214
# consumo_prom_no_dom     37440
# bimestre                    3
# consumo_total_no_dom    27336
# gid                     71102
# indice_des                  4
# dtype: int64

# %% [markdown]
# ¿Cuántas variables numéricas tenemos?
#
# ¿Cuántas variables de fecha tenemos?
#
# ¿Cuántas variables categóricas tenemos?
#
# ¿Cuántas variables de texto tenemos?

# %%
df_consumo_agua.dtypes
# Out:
# Geo Point                object
# Geo Shape                object
# consumo_total_mixto     float64
# anio                      int64
# nomgeo                   object
# consumo_prom_dom        float64
# consumo_total_dom       float64
# alcaldia                 object
# colonia                  object
# consumo_prom_mixto      float64
# consumo_total           float64
# consumo_prom            float64
# consumo_prom_no_dom     float64
# bimestre                  int64
# consumo_total_no_dom    float64
# gid                       int64
# indice_des               object
# dtype: object

# %%
df_consumo_agua.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71102 entries, 0 to 71101
# Data columns (total 17 columns):
# Geo Point               71102 non-null object
# Geo Shape               71078 non-null object
# consumo_total_mixto     62775 non-null float64
# anio                    71102 non-null int64
# nomgeo                  71102 non-null object
# consumo_prom_dom        66282 non-null float64
# consumo_total_dom       66282 non-null float64
# alcaldia                71102 non-null object
# colonia                 71102 non-null object
# consumo_prom_mixto      62775 non-null float64
# consumo_total           71102 non-null float64
# consumo_prom            71102 non-null float64
# consumo_prom_no_dom     71102 non-null float64
# bimestre                71102 non-null int64
# consumo_total_no_dom    71102 non-null float64
# gid                     71102 non-null int64
# indice_des              71102 non-null object
# dtypes: float64(8), int64(3), object(6)
# ...

# %% [markdown]
# Generea el profiling de cada variable

# %%
df_consumo_agua.describe() #Da el conteo de observaciones, media, desv. estándar mín, máx, quantiles excluyendo NaN
# Out:
#        consumo_total_mixto     anio  consumo_prom_dom  consumo_total_dom  \
# count         62775.000000  71102.0      66282.000000       66282.000000
# mean            174.359929   2019.0         29.132386        1186.263611
# std             312.663596      0.0         64.565925        2771.038307
# min               0.000000   2019.0          0.000000           0.000000
# 25%               0.000000   2019.0         18.690547         161.635000
# 50%              79.940000   2019.0         26.414248         604.185000
# 75%             233.320000   2019.0         36.246563        1261.445000
# max           23404.440000   2019.0       7796.410000       95060.690000
#
#        consumo_prom_mixto  consumo_total  consumo_prom  consumo_prom_no_dom  \
# count        62775.000000   71102.000000  71102.000000         71102.000000
# mean            50.636234    1695.847222    111.217399           126.760172
# std            130.408673    3555.697457   1069.949262          1095.817805
# ...

# %% [markdown]
# ¿Qué conocemos ahora de este set de datos por variable?

# %% [markdown]
# ¿Cuántas alcadías tienes?

# %%
df_consumo_agua.alcaldia.nunique()
# Out:
# 16

# %% [markdown]
# Son 16 alcaldías, sus valores únicos son:

# %%
df_consumo_agua.alcaldia.unique()
# Out:
# array(['AZCAPOTZALCO', 'VENUSTIANO CARRANZA', 'MILPA ALTA', 'TLALPAN',
#        'ALVARO OBREGON', 'COYOACAN', 'BENITO JUAREZ', 'TLAHUAC',
#        'MAGDALENA CONTRERAS', 'GUSTAVO A. MADERO', 'CUAJIMALPA',
#        'IZTAPALAPA', 'XOCHIMILCO', 'IZTACALCO', 'CUAUHTEMOC',
#        'MIGUEL HIDALGO'], dtype=object)

# %% [markdown]
# ¿Cuántos nomgeo tienes?

# %%
df_consumo_agua.nomgeo.nunique()
# Out:
# 17

# %% [markdown]
# Son 17 nomgeo, sus valores únicos son:

# %%
df_consumo_agua.nomgeo.unique()
# Out:
# array(['Azcapotzalco', 'Venustiano Carranza', 'Milpa Alta', 'Tlalpan',
#        'Álvaro Obregón', 'Coyoacán', 'Benito Juárez', 'Tláhuac',
#        'La Magdalena Contreras', 'Gustavo A. Madero',
#        'Cuajimalpa de Morelos', 'Iztapalapa', 'Xochimilco', 'Iztacalco',
#        'Cuauhtémoc', 'Talpan', 'Miguel Hidalgo'], dtype=object)

# %% [markdown]
# ¿Identificas algún error?
# Sí, hay un error de captura en la alcaldía de Tlalpan con Talpan

# %% [markdown]
#  To Do, 26 septiembre 2019
#
# Transformar las variables a formato estándar: minúsculas, sin espacios en blanco, sin signos de puntuación.

# %%
# Out:
#                           Geo Point  \
# 0      19.4982924872,-99.1990438826
# 1      19.4988910559,-99.2009080554
# 2      19.4808107353,-99.2087681126
# 3      19.4815775288,-99.2034616053
# 4      19.4794098214,-99.2027692099
# 5        19.4975265487,-99.21195176
# 6      19.4966164619,-99.1930681289
# 7       19.4900746324,-99.196630624
# 8      19.4840235824,-99.2103915833
# 9       19.498490991,-99.2009884028
# 10     19.4885632293,-99.2031811727
# 11     19.4838426741,-99.2120563592
# 12     19.4885632293,-99.2031811727
# 13     19.4938030532,-99.2140930535
# 14     19.4955312206,-99.1996191463
# 15     19.4311310364,-99.1210559573
# 16     19.4972213126,-99.2115731442
# 17     19.4967520855,-99.2105402569
# 18     19.4968695952,-99.2097730685
# 19     19.4956006378,-99.2097079295
# 20      19.480339316,-99.2192385683
# 21      19.4958193012,-99.210833036
# 22     19.4964979586,-99.2127640154
# 23     19.5046778297,-99.2091968959
# 24     19.5025781461,-99.2076315381
# ...

# %%
df_consumo_agua.apply(lambda x: x.astype(str).str.lower()) #convierte a minúsculas las observaciones de tipo string
# Out:
#                           Geo Point  \
# 0      19.4982924872,-99.1990438826
# 1      19.4988910559,-99.2009080554
# 2      19.4808107353,-99.2087681126
# 3      19.4815775288,-99.2034616053
# 4      19.4794098214,-99.2027692099
# 5        19.4975265487,-99.21195176
# 6      19.4966164619,-99.1930681289
# 7       19.4900746324,-99.196630624
# 8      19.4840235824,-99.2103915833
# 9       19.498490991,-99.2009884028
# 10     19.4885632293,-99.2031811727
# 11     19.4838426741,-99.2120563592
# 12     19.4885632293,-99.2031811727
# 13     19.4938030532,-99.2140930535
# 14     19.4955312206,-99.1996191463
# 15     19.4311310364,-99.1210559573
# 16     19.4972213126,-99.2115731442
# 17     19.4967520855,-99.2105402569
# 18     19.4968695952,-99.2097730685
# 19     19.4956006378,-99.2097079295
# 20      19.480339316,-99.2192385683
# 21      19.4958193012,-99.210833036
# 22     19.4964979586,-99.2127640154
# 23     19.5046778297,-99.2091968959
# 24     19.5025781461,-99.2076315381
# ...

# %% [markdown]
# Agregar la variable latitud y longitud.

# %% [markdown]
# Pasar la variable latitud y longitud a numérica -si no la tomó como numérica-.

# %% [markdown]
# Eliminar la columna geo_point -una vez que creaste la variable latitud y longitud.

# %% [markdown]
# Eliminar la columna geo_shape.

# %% [markdown]
# Cambiar a minúsculas las columnas alcaldía, colonia e indice_des.

# %%
df_consumo_agua.apply(lambda x: x.astype(str).str.lower()) #convierte a minúsculas las observaciones de tipo stri

# %% [markdown]
# Volver a correr el proceso de identificación de variables numéricas, categóricas, texto y fechas.

# %% [markdown]
# Genera el data profiling por variable.
